# %%
# Veri işleme ve analiz kütüphaneleri
# !pip install pandas numpy scikit-learn

# Veri görselleştirme kütüphaneleri
# !pip install matplotlib seaborn

# Coğrafi bilgi sistemleri (GIS) kütüphaneleri
# !pip install geopandas folium

# ETL süreçleri ve veri entegrasyonu için ek kütüphaneler
# !pip install sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    ------- -------------------------------- 61.4/323.6 kB ? eta -:--:--
#    ------------ --------------------------- 102.4/323.6 kB 1.5 MB/s eta 0:00:01
#    -------------- ----------------------- 122.9/323.6 kB 901.1 kB/s eta 0:00:01
#    -------------- ----------------------- 122.9/323.6 kB 901.1 kB/s eta 0:00:01
#    ---------------- --------------------- 143.4/323.6 kB 711.9 kB/s eta 0:00:01
#    -------------------- ----------------- 174.1/323.6 kB 655.4 kB/s eta 0:00:01
#    ------------------------ ------------- 204.8/323.6 kB 623.6 kB/s eta 0:00:01
#    ------------------------ ------------- 204.8/323.6 kB 623.6 kB/s eta 0:00:01
#    -------------------------- ----------- 225.3/323.6 kB 573.4 kB/s eta 0:00:01
# ...

# %%
# Importing necessary libraries for data processing and analysis
import pandas as pd  # Pandas is used for data manipulation and analysis
import numpy as np   # NumPy is used for numerical operations and handling arrays

# Importing libraries for machine learning and statistical analysis
from sklearn.model_selection import train_test_split  # Splitting data into training and test sets
from sklearn.linear_model import LinearRegression     # Linear Regression model
from sklearn.metrics import mean_squared_error, r2_score  # Performance metrics
from sklearn.preprocessing import StandardScaler      # Scaling data before modeling

# Importing libraries for data visualization
import matplotlib.pyplot as plt  # Matplotlib is used for creating static, animated, and interactive visualizations
import seaborn as sns            # Seaborn is used for making statistical graphics
import plotly.express as px      # Plotly is used for creating interactive plots

# Importing libraries for Geographic Information Systems (GIS) analysis
import geopandas as gpd  # GeoPandas is used for working with geospatial data
import folium            # Folium is used for creating interactive maps

# Importing SQLAlchemy for ETL processes and data integration
from sqlalchemy import create_engine  # SQLAlchemy is used for connecting to and interacting with databases

# Importing tools for working with dates and times
import datetime as dt  # datetime is used for manipulating dates and times
import calendar        # calendar is used for calendar-related functions

# Importing tools for handling file paths and directories
import os              # os is used for interacting with the operating system and handling file paths
import glob            # glob is used for finding all the pathnames matching a specified pattern

# Importing tools for performance monitoring and optimization
import time            # time is used for tracking execution time of code blocks
import memory_profiler # memory_profiler is used for monitoring memory usage

# Importing tools for working with JSON and CSV files
import json            # json is used for parsing and working with JSON data
import csv             # csv is used for reading and writing CSV files

# Importing tools for debugging and error handling
import logging         # logging is used for tracking events that happen when the software runs
import traceback       # traceback is used for printing detailed error information

# Setting up options for better readability and display of data in the notebook
pd.set_option('display.max_columns', None)  # Display all columns of dataframes
pd.set_option('display.max_rows', 100)      # Display more rows for large datasets
